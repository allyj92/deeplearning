# %% [markdown]
# <a href="https://colab.research.google.com/github/allyj92/deeplearning/blob/main/travel_insurance_ml_modeling_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Travel Insurance Prediction
#
# - 데이터 다운로드 : https://www.kaggle.com/datasets/tejashvi14/travel-insurance-prediction-data
#
# - 제공된 데이터
#     - train.csv
#     - test.csv
#     - target columns: `TravelInsurance`
#     - 0: 미가입, 1: 가입
#
# - 주어진 학습 데이터세트를 사용하여 고객별 여행 보험 가입 여부를 예측하시오

# %% [markdown]
# ## 데이터 읽기

# %%
# 판다스 임포트
import pandas as pd

# %%
# 데이터 불러오기
X = pd.read_csv('train.csv')
X_test = pd.read_csv('test.csv')
y_test = pd.read_csv('y_test.csv')
y_test
# Out:
#      Unnamed: 0  TravelInsurance
# 0          1115                0
# 1          1193                0
# 2          1804                0
# 3          1461                0
# 4           332                1
# ..          ...              ...
# 393         563                1
# 394          32                1
# 395        1349                1
# 396        1400                0
# 397        1785                0
#
# [398 rows x 2 columns]

# %%
X_test
# Out:
#      Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 0          1115   34  Private Sector/Self Employed           Yes
# 1          1193   34  Private Sector/Self Employed            No
# 2          1804   28  Private Sector/Self Employed           Yes
# 3          1461   31             Government Sector            No
# 4           332   31  Private Sector/Self Employed           Yes
# ..          ...  ...                           ...           ...
# 393         563   33  Private Sector/Self Employed           Yes
# 394          32   25             Government Sector           Yes
# 395        1349   26  Private Sector/Self Employed           Yes
# 396        1400   29  Private Sector/Self Employed           Yes
# 397        1785   25  Private Sector/Self Employed            No
#
#      AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0          700000              2                0            No
# 1          950000              3                0            No
# 2         1100000              5                0            No
# 3          400000              8                0            No
# 4         1650000              7                1           Yes
# ..            ...            ...              ...           ...
# 393        550000              3                1            No
# 394        750000              4                0            No
# 395       1400000              3                0            No
# 396       1050000              6                1           Yes
# 397       1150000              2                0            No
#
#     EverTravelledAbroad
# 0                    No
# 1                    No
# 2                    No
# 3                    No
# 4                    No
# ..                  ...
# 393                  No
# 394                  No
# 395                 Yes
# 396                  No
# 397                 Yes
#
# [398 rows x 9 columns]

# %% [markdown]
# ## 둘러보기

# %%
# train head: 타겟 컬럼을 포함하고 있음
y_train = X['TravelInsurance']
X_train = X.drop(columns = ['TravelInsurance'])

# %%
# test head
X_test = X_test.drop(columns=['Unnamed: 0'])

# %%
y_test = y_test.drop(columns=['Unnamed: 0'])

# %%
# 타겟 분포 확인: 0, 1이 균일 한지 판단

# %%
# 수치형 변수 기초 통계 획인

# %%
# ChronicDiseases컬럼은 기초 통계를 보면
# 0, 1로 인코딩 되어 있지만 그냥 범주형으로 보는게 맞음
X['ChronicDiseases'].value_counts()
# Out:
# ChronicDiseases
# 0    1149
# 1     440
# Name: count, dtype: int64

# %%
# 범주형 변수 기초 통계 확인

# %%
# 데이터 타입 및 결측치 확인
y_train.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 데이터 전처리

# %%
# 컬럼 분리
# 둘러보기에서 범주형 변수로 처리하기로 한 ChronicDiseases 도 범주형 변수로 함께 처리

# 다음 변수를 ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad', 'ChronicDiseases']
# 로 설정
CAT_VARS = ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad', 'ChronicDiseases']

# 다음 변수를 ['Age', 'AnnualIncome', 'FamilyMembers']
# 로 설정
NUM_VARS = ['Age', 'AnnualIncome', 'FamilyMembers']

print(CAT_VARS)
print(NUM_VARS)
# Out:
# ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad', 'ChronicDiseases']
# ['Age', 'AnnualIncome', 'FamilyMembers']

# %%
# train, valid 분리, test_size=0.2, stratify 옵션 지정
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X_train,y_train, test_size=0.2)

# %% [markdown]
# ### 범주형 변수 인코딩

# %%
# CAT_VARS encoding

X_train = pd.get_dummies(X_train, columns= ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad', 'ChronicDiseases'],drop_first=True)
X_train
# Out:
#       Unnamed: 0  Age  AnnualIncome  FamilyMembers  \
# 646         1936   33       1500000              7
# 593          559   29       1200000              3
# 927          995   27        850000              5
# 1512         243   26        750000              6
# 535         1439   33        400000              7
# ...          ...  ...           ...            ...
# 621          280   32        800000              6
# 235         1313   29        900000              7
# 635          327   34       1300000              3
# 703          587   29        900000              9
# 1500        1384   34       1000000              4
#
#       Employment Type_Private Sector/Self Employed  GraduateOrNot_Yes  \
# 646                                           True               True
# 593                                           True               True
# 927                                          False               True
# 1512                                          True               True
# 535                                          False               True
# ...                                            ...                ...
# 621                                          False               True
# 235                                           True               True
# 635                                          False               True
# 703                                           True               True
# 1500                                          True               True
#
#       FrequentFlyer_Yes  EverTravelledAbroad_Yes  ChronicDiseases_1
# 646                True                     True              False
# 593               False                    False              False
# 927               False                    False              False
# 1512              False                    False              False
# 535               False                    False               True
# ...                 ...                      ...                ...
# 621                True                    False              False
# 235               False                    False              False
# 635               False                    False              False
# 703               False                    False               True
# 1500               True                    False              False
#
# [1271 rows x 9 columns]

# %%
X_test = pd.get_dummies(X_test, columns= ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad', 'ChronicDiseases'],drop_first=True)

# %%
X_valid = pd.get_dummies(X_valid, columns= ['Employment Type', 'GraduateOrNot', 'FrequentFlyer', 'EverTravelledAbroad', 'ChronicDiseases'],drop_first=True)

# %% [markdown]
# ### 수치형 변수 스케일링

# %%
X_train.dtypes
# Out:
# Unnamed: 0                                      int64
# Age                                             int64
# AnnualIncome                                    int64
# FamilyMembers                                   int64
# Employment Type_Private Sector/Self Employed     bool
# GraduateOrNot_Yes                                bool
# FrequentFlyer_Yes                                bool
# EverTravelledAbroad_Yes                          bool
# ChronicDiseases_1                                bool
# dtype: object

# %%
# NUM_VARS scaling, StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train[NUM_VARS] = scaler.fit_transform(X_train[NUM_VARS])

X_train
# Out:
#       Unnamed: 0       Age  AnnualIncome  FamilyMembers  \
# 646         1936  1.139153      1.510535       1.397868
# 593          559 -0.230957      0.709190      -1.113355
# 927          995 -0.916012     -0.225713       0.142257
# 1512         243 -1.258539     -0.492829       0.770062
# 535         1439  1.139153     -1.427732       1.397868
# ...          ...       ...           ...            ...
# 621          280  0.796626     -0.359271       0.770062
# 235         1313 -0.230957     -0.092156       1.397868
# 635          327  1.481681      0.976305      -1.113355
# 703          587 -0.230957     -0.092156       2.653480
# 1500        1384  1.481681      0.174959      -0.485549
#
#       Employment Type_Private Sector/Self Employed  GraduateOrNot_Yes  \
# 646                                           True               True
# 593                                           True               True
# 927                                          False               True
# 1512                                          True               True
# 535                                          False               True
# ...                                            ...                ...
# 621                                          False               True
# 235                                           True               True
# 635                                          False               True
# 703                                           True               True
# 1500                                          True               True
#
#       FrequentFlyer_Yes  EverTravelledAbroad_Yes  ChronicDiseases_1
# 646                True                     True              False
# 593               False                    False              False
# 927               False                    False              False
# 1512              False                    False              False
# 535               False                    False               True
# ...                 ...                      ...                ...
# 621                True                    False              False
# 235               False                    False              False
# 635               False                    False              False
# 703               False                    False               True
# 1500               True                    False              False
#
# [1271 rows x 9 columns]

# %%
X_test[NUM_VARS] = scaler.fit_transform(X_test[NUM_VARS])

X_test
# Out:
#           Age  AnnualIncome  FamilyMembers  \
# 0    1.474105     -0.577815      -1.654038
# 1    1.474105      0.069624      -1.047304
# 2   -0.599018      0.458088       0.166166
# 3    0.437544     -1.354743       1.986370
# 4    0.437544      1.882455       1.379636
# ..        ...           ...            ...
# 393  1.128584     -0.966279      -1.047304
# 394 -1.635579     -0.448327      -0.440569
# 395 -1.290059      1.235015      -1.047304
# 396 -0.253497      0.328600       0.772901
# 397 -1.635579      0.587576      -1.654038
#
#      Employment Type_Private Sector/Self Employed  GraduateOrNot_Yes  \
# 0                                            True               True
# 1                                            True              False
# 2                                            True               True
# 3                                           False              False
# 4                                            True               True
# ..                                            ...                ...
# 393                                          True               True
# 394                                         False               True
# 395                                          True               True
# 396                                          True               True
# 397                                          True              False
#
#      FrequentFlyer_Yes  EverTravelledAbroad_Yes  ChronicDiseases_1
# 0                False                    False              False
# 1                False                    False              False
# 2                False                    False              False
# 3                False                    False              False
# 4                 True                    False               True
# ..                 ...                      ...                ...
# 393              False                    False               True
# 394              False                    False              False
# 395              False                     True              False
# 396               True                    False               True
# 397              False                     True              False
#
# [398 rows x 8 columns]

# %%
X_valid[NUM_VARS] = scaler.fit_transform(X_valid[NUM_VARS])

X_valid
# Out:
#       Unnamed: 0       Age  AnnualIncome  FamilyMembers  \
# 1481         613  0.534760      0.834086       0.798006
# 1308        1658  1.914505      0.032355       0.798006
# 325         1916 -0.500049      0.433220       0.798006
# 1296         924  0.534760     -1.437485       0.798006
# 429          212 -0.500049     -0.502132       0.182069
# ...          ...       ...           ...            ...
# 453         1950 -0.500049      0.834086       0.798006
# 1261         861  0.189823      1.368573      -1.049804
# 165         1537 -0.155113     -1.170241      -0.433867
# 19          1369  1.569568     -0.502132      -0.433867
# 1118         367  0.534760      0.967707      -0.433867
#
#       Employment Type_Private Sector/Self Employed  GraduateOrNot_Yes  \
# 1481                                          True               True
# 1308                                          True              False
# 325                                          False               True
# 1296                                         False               True
# 429                                           True               True
# ...                                            ...                ...
# 453                                           True               True
# 1261                                          True              False
# 165                                           True               True
# 19                                            True              False
# 1118                                         False               True
#
#       FrequentFlyer_Yes  EverTravelledAbroad_Yes  ChronicDiseases_1
# 1481              False                    False              False
# 1308              False                     True              False
# 325               False                    False               True
# 1296              False                    False              False
# 429               False                    False               True
# ...                 ...                      ...                ...
# 453               False                     True              False
# 1261               True                     True               True
# 165               False                    False              False
# 19                 True                    False              False
# 1118              False                    False              False
#
# [318 rows x 9 columns]

# %% [markdown]
# ## 모델링 및 평가

# %%
# model import, RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

# %%
# model fit
rf = RandomForestClassifier(n_estimators=5, random_state=0)
rf.fit(X_train, y_train)
rf_predict = rf.predict(X_train)

# %%
# roc_auc_score로 X_train, X_valid에 대해서 성능 측정
from sklearn.metrics import roc_auc_score
roc_auc_score=roc_auc_score(y_train, rf_predict)
roc_auc_score
# Out:
# 0.9741685144124168

# %% [markdown]
# ## 예측

# %%
# 확률로 예측

# %%
# 레이블로 예측

# %% [markdown]
# ## 채점
#
# - 이 과정은 `submit.csv`를 사용하여 시험 출제자가 채점하는 코드로 시험과는 상관없는 부분

# %%
# 예측을 데이터 프레임으로 만들어 csv파일로 저장
pd.DataFrame(
    {'TravelInsurance':rf.predict_proba(X_test)[:,1]},
    index=X_test.index
).to_csv('submit.csv')

# 정답 파일 불러오기
y_test = pd.read_csv('y_test.csv', index_col=0)
y_test

y_pred_test = pd.read_csv('submit.csv', index_col=0)

def score(file):
    submit = pd.read_csv(file, index_col=0)
    return roc_auc_score(
        y_test.sort_index()['TravelInsurance'],
        y_pred_test.sort_index()['TravelInsurance']
    )

print(score('submit.csv'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-12cd777b7920> in <cell line: 2>()
#       1 # 예측을 데이터 프레임으로 만들어 csv파일로 저장
#       2 pd.DataFrame(
# ----> 3     {'TravelInsurance':rf.predict_proba(X_test)[:,1]},
#       4     index=X_test.index
#       5 ).to_csv('submit.csv')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     944         check_is_fitted(self)
#     945         # Check data
# --> 946         X = self._validate_X_predict(X)
#     947
#     948         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     639             force_all_finite = True
#     640
# --> 641         X = self._validate_data(
#     642             X,
#     643             dtype=DTYPE,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     606             validated.
#     607         """
# --> 608         self._check_feature_names(X, reset=reset)
#     609
#     610         if y is None and self._get_tags()["requires_y"]:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _check_feature_names(self, X, reset)
#     533                 )
#     534
# --> 535             raise ValueError(message)
#     536
#     537     def _validate_data(
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - Unnamed: 0

# %% [markdown]
# ---

# %%
# [추가 수행 과제] 그리드 서치

param_grid = {
    'n_estimators':[100, 130, 150],
    'max_depth':[8, 10, 12],
    'min_samples_leaf':[2, 3, 5]
}

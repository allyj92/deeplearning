# %% [markdown]
# # **Deep Learning Programming with Python**
# ### Week2: Matplotlib 101
#
# **Acknowledgement**
#
# Many of Today's contents are adopted from the below resources:
#
# 1. https://medium.com/analytics-vidhya/matplotlib-4aa9ee8804fb
# ----

# %% [markdown]
# ##Matplotlib
#
# Matplotlib is a plotting library.
#
# In this section give a brief introduction to the matplotlib.pyplot module, which provides a plotting system similar to that of MATLAB.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# By running this special iPython command, we will be **displaying plots inline**:

# %%
# %matplotlib inline

# %% [markdown]
# ### Plotting
#
# The most important function in matplotlib is plot, which allows you to plot 2D data. Here is a simple example:

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)

# %% [markdown]
# With just a little bit of extra work we can easily plot multiple lines at once, and add a title, legend, and axis labels:

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label!')
plt.ylabel('y axis label?')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

# %% [markdown]
# ### Histogram Plot
#
# A graphical display of data using bars of different heights

# %%
x = [1,2,3,5,6,7]
plt.hist(x) # plt.hist is used to plot histogram plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Bar plot
#
# A graphical display of data using bars of different heights.

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.bar(x,y)
plt.show()

# %% [markdown]
# ### Scatter plot
#
# A graph of plotted points that show the relationship between two sets of data.

# %%
plt.scatter([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.axis([0,6, 0, 30])
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ### With third argument
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot.

# %%
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25], 'ro')
plt.axis([0,6, 0, 30])
plt.show()

# %% [markdown]
# ### With Numpy arrrays
#
# We can use matplotlib with Numpy arrays.
# In fact, all sequences in the matplotlib are converted to numpy arrays internally.

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares, and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Pie Chart
#
# A pie chart (or a circle chart) is a circular statistical graphic, which is divided into slices to illustrate numerical proportion.

# %%
slice = [2,4,8,16]
activities = ['code', 'eat', 'sleep', 'work']
color = ['r', 'g', 'b', 'c']
plt.pie(slice, labels = activities, colors = color, startangle = 45)
plt.show()

# %% [markdown]
# ### Subplots
#
# You can plot different things in the same figure using the subplot function. Here is an example:

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Rhe position of the subplot described by one of Three integers (nrows, ncols, index)
plt.subplot(2, 2, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')
plt.subplot(2, 2, 4)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# You can read much more about the `subplot` function in the [documentation](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot).
